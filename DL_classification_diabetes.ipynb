# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("diabetes.csv", index_col=0)
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.countplot(data = df, x="Outcome")
plt.xlabel("Diabetes or Not")
plt.ylabel("Count")
plt.title("Outcome")
# Out:
# Text(0.5, 1.0, 'Outcome')

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
figure = plt.figure(figsize=(18,6))
ax1 = plt.subplot(1,2,1)
sns.distplot(df['Glucose'], kde = True, hist = False, ax=ax1)
ax2 = plt.subplot(1,2,2)
sns.distplot(df['BMI'], ax=ax2)
# Out:
# C:\Users\calix\AppData\Local\Temp\ipykernel_1848\918732697.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Glucose'], kde = True, hist = False, ax=ax1)
# C:\Users\calix\AppData\Local\Temp\ipykernel_1848\918732697.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BMI'], ax=ax2)
# <Axes: xlabel='BMI', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(df['Glucose'], df['BMI'])
plt.xlabel('Glucose')
plt.ylabel('BMI')

plt.show()

# %%
sns.pairplot(df,
             vars=['Glucose', 'BloodPressure', 'Insulin', 'BMI'],
            hue ='Outcome')
plt.show()

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(x="Glucose", data=df, palette="Set3")
plt.title("Glucose")
plt.show()
# Out:
# C:\Users\calix\AppData\Local\Temp\ipykernel_1848\3994245020.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Glucose", data=df, palette="Set3")

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
plt.show()
# Out:
# C:\Users\calix\AppData\Local\Temp\ipykernel_1848\111277950.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax = ax)

# %%
X=df.drop('Outcome',axis=1)
X.head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
#
#              DiabetesPedigreeFunction  Age
# Pregnancies
# 6                               0.627   50
# 1                               0.351   31
# 8                               0.672   32
# 1                               0.167   21
# 0                               2.288   33

# %%
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1
# ...                               ...  ...      ...
# 10                              0.171   63        0
# 2                               0.340   27        0
# 5                               0.245   30        0
# 1                               0.349   47        1
# 1                               0.315   23        0
#
# [768 rows x 8 columns]

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
y.head()
# Out:
# Pregnancies
# 6    1
# 1    0
# 8    1
# 1    0
# 0    1
# Name: Outcome, dtype: int64

# %%
Y = pd.get_dummies(y).values

# %%
X = X.values

# %%
X
# Out:
# array([[148.   ,  72.   ,  35.   , ...,  33.6  ,   0.627,  50.   ],
#        [ 85.   ,  66.   ,  29.   , ...,  26.6  ,   0.351,  31.   ],
#        [183.   ,  64.   ,   0.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [121.   ,  72.   ,  23.   , ...,  26.2  ,   0.245,  30.   ],
#        [126.   ,  60.   ,   0.   , ...,  30.1  ,   0.349,  47.   ],
#        [ 93.   ,  70.   ,  31.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
y
# Out:
# Pregnancies
# 6     1
# 1     0
# 8     1
# 1     0
# 0     1
#      ..
# 10    0
# 2     0
# 5     0
# 1     1
# 1     0
# Name: Outcome, Length: 768, dtype: int64

# %%
Y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(7,),activation='tanh'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(2,activation='softmax'))

model.compile(Adam(learning_rate=0.04),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# C:\Users\calix\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 10)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 8)              │            88 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 6)              │            54 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │            14 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 236 (944.00 B)
#  Trainable params: 236 (944.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5847 - loss: 0.6905 - val_accuracy: 0.6948 - val_loss: 0.6279
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5217 - loss: 0.6812 - val_accuracy: 0.6948 - val_loss: 0.6381
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5975 - loss: 0.6797 - val_accuracy: 0.6948 - val_loss: 0.6157
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6213 - loss: 0.6782 - val_accuracy: 0.6948 - val_loss: 0.6156
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6560 - loss: 0.6479 - val_accuracy: 0.6948 - val_loss: 0.6311
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6610 - loss: 0.6490 - val_accuracy: 0.6948 - val_loss: 0.6257
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6426 - loss: 0.6593 - val_accuracy: 0.6948 - val_loss: 0.6554
# Epoch 8/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6662 - loss: 0.6597 - val_accuracy: 0.6948 - val_loss: 0.6386
# Epoch 9/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5823 - loss: 0.6744 - val_accuracy: 0.6948 - val_loss: 0.6497
# Epoch 10/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5653 - loss: 0.6770 - val_accuracy: 0.6948 - val_loss: 0.6526
# Epoch 11/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6684 - loss: 0.6558 - val_accuracy: 0.6948 - val_loss: 0.6588
# Epoch 12/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6459 - loss: 0.6676 - val_accuracy: 0.6948 - val_loss: 0.6636
# Epoch 13/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6318 - loss: 0.6724 - val_accuracy: 0.6948 - val_loss: 0.6156
# Epoch 14/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6169 - loss: 0.6805 - val_accuracy: 0.6948 - val_loss: 0.6152
# Epoch 15/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6209 - loss: 0.6713 - val_accuracy: 0.6948 - val_loss: 0.6152
# Epoch 16/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6318 - loss: 0.6663 - val_accuracy: 0.6948 - val_loss: 0.6155
# Epoch 17/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6528 - loss: 0.6601 - val_accuracy: 0.6948 - val_loss: 0.6703
# Epoch 18/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6278 - loss: 0.6690 - val_accuracy: 0.6948 - val_loss: 0.6180
# Epoch 19/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6277 - loss: 0.6639 - val_accuracy: 0.6948 - val_loss: 0.6150
# Epoch 20/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6589 - loss: 0.6463 - val_accuracy: 0.6948 - val_loss: 0.6637
# Epoch 21/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6628 - loss: 0.6699 - val_accuracy: 0.6948 - val_loss: 0.6407
# Epoch 22/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6367 - loss: 0.6554 - val_accuracy: 0.6948 - val_loss: 0.6600
# Epoch 23/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6568 - loss: 0.6697 - val_accuracy: 0.6948 - val_loss: 0.6236
# Epoch 24/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6303 - loss: 0.6675 - val_accuracy: 0.6948 - val_loss: 0.6179
# Epoch 25/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6391 - loss: 0.6593 - val_accuracy: 0.6948 - val_loss: 0.6171
# Epoch 26/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6430 - loss: 0.6627 - val_accuracy: 0.6948 - val_loss: 0.6206
# Epoch 27/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6396 - loss: 0.6558 - val_accuracy: 0.6948 - val_loss: 0.6568
# Epoch 28/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6395 - loss: 0.6687 - val_accuracy: 0.6948 - val_loss: 0.6204
# Epoch 29/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6348 - loss: 0.6556 - val_accuracy: 0.6948 - val_loss: 0.6202
# Epoch 30/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6248 - loss: 0.6880 - val_accuracy: 0.6948 - val_loss: 0.6153
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82       107
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.69       154
#    macro avg       0.35      0.50      0.41       154
# weighted avg       0.48      0.69      0.57       154
#
# [[107   0]
#  [ 47   0]]
# C:\Users\calix\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\calix\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\calix\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
